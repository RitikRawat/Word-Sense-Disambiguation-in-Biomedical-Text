# %%
import pandas as pd
import xml.etree.ElementTree as ET
import spacy
import numpy as np
from pathlib import Path
import os
# Out:
# 2024-01-12 13:32:01.675585: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2024-01-12 13:32:01.675644: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:163] no NVIDIA GPU device is present: /dev/nvidia0 does not exist

# %%
files = Path("Tokens/").glob('*.txt')

# %%
freq ={}

# %%
curr =0
for file in files:
    curr+=1
    name =  os.path.basename(file)
    with open(file,'r') as f:
        lines = f.readlines()
        for line in lines:
            tokens = line.split()
            for token in tokens:
                if token in freq:
                    freq[token]+=1
                else:
                    freq[token] =1
    print(f'{curr} : {name}')
# Out:
# 1 : 144.txt
# 2 : 282.txt
# 3 : 525.txt
# 4 : 253.txt
# 5 : 195.txt
# 6 : 138.txt
# 7 : 377.txt
# 8 : 401.txt
# 9 : 228.txt
# 10 : 370.txt
# 11 : 406.txt
# 12 : 143.txt
# 13 : 522.txt
# 14 : 285.txt
# 15 : 254.txt
# 16 : 192.txt
# 17 : 131.txt
# 18 : 550.txt
# 19 : 226.txt
# 20 : 408.txt
# 21 : 302.txt
# 22 : 474.txt
# 23 : 305.txt
# 24 : 473.txt
# 25 : 379.txt
# 26 : 462.txt
# 27 : 314.txt
# 28 : 368.txt
# 29 : 230.txt
# 30 : 127.txt
# 31 : 546.txt
# 32 : 419.txt
# 33 : 237.txt
# 34 : 120.txt
# 35 : 541.txt
# 36 : 465.txt
# 37 : 313.txt
# 38 : 417.txt
# 39 : 361.txt
# 40 : 239.txt
# 41 : 245.txt
# 42 : 183.txt
# 43 : 152.txt
# 44 : 294.txt
# 45 : 533.txt
# 46 : 242.txt
# 47 : 184.txt
# 48 : 155.txt
# 49 : 534.txt
# 50 : 293.txt
# 51 : 410.txt
# 52 : 366.txt
# 53 : 129.txt
# 54 : 548.txt
# 55 : 488.txt
# 56 : 459.txt
# 57 : 501.txt
# 58 : 160.txt
# 59 : 277.txt
# 60 : 353.txt
# 61 : 425.txt
# 62 : 382.txt
# 63 : 354.txt
# 64 : 385.txt
# 65 : 422.txt
# 66 : 328.txt
# 67 : 506.txt
# 68 : 167.txt
# 69 : 270.txt
# 70 : 115.txt
# 71 : 202.txt
# 72 : 481.txt
# 73 : 326.txt
# 74 : 450.txt
# 75 : 508.txt
# 76 : 169.txt
# 77 : 321.txt
# 78 : 486.txt
# 79 : 457.txt
# 80 : 279.txt
# 81 : 112.txt
# 82 : 205.txt
# 83 : 8.txt
# 84 : 6.txt
# 85 : 1.txt
# 86 : 71.txt
# 87 : 76.txt
# 88 : 78.txt
# 89 : 36.txt
# 90 : 31.txt
# 91 : 92.txt
# 92 : 43.txt
# 93 : 38.txt
# 94 : 95.txt
# 95 : 44.txt
# 96 : 12.txt
# 97 : 69.txt
# 98 : 15.txt
# 99 : 67.txt
# 100 : 60.txt

# %%
len(freq)
# Out:
# 5580425

# %%
 freq = {k: v for k, v in sorted(freq.items(), key=lambda item: item[1],reverse=True)}

# %%
del freq['-']

# %%
freq
# Out:
# {'patients': 1575647,
#  'cells': 1011785,
#  'results': 748770,
#  'study': 731502,
#  'treatment': 608978,
#  'cell': 602188,
#  'activity': 511927,
#  'protein': 475410,
#  'group': 471515,
#  'effect': 442695,
#  'human': 430457,
#  'disease': 422303,
#  'effects': 412852,
#  'increased': 403328,
#  'levels': 397733,
#  'clinical': 385952,
#  'found': 378535,
#  'analysis': 370232,
#  'expression': 368921,
#  'data': 354243,
#  'significantly': 353935,
#  'studies': 340671,
#  'significant': 340334,
#  'blood': 337779,
#  'compared': 336447,
#  'control': 323608,
#  'different': 318650,
#  'gene': 316104,
#  'associated': 314958,
#  'cases': 313572,
#  'showed': 311233,
#  'high': 308785,
#  'response': 297228,
#  'observed': 293173,
#  'use': 289142,
#  'normal': 287928,
#  'acid': 282929,
#  'years': 280436,
#  'methods': 280030,
#  'rate': 277047,
#  'changes': 274659,
#  'cancer': 274558,
#  'time': 274414,
#  'patient': 267675,
#  'system': 266260,
#  'rats': 265996,
#  'increase': 263599,
#  'role': 255246,
#  'age': 254844,
#  'present': 252286,
#  'groups': 250796,
#  'therapy': 245834,
#  'higher': 243181,
#  'growth': 242574,
#  'dna': 240481,
#  'new': 239324,
#  'function': 236686,
#  'risk': 234173,
#  'method': 228889,
#  'binding': 228178,
#  'children': 227976,
#  'mice': 225650,
#  'plasma': 220575,
#  'mean': 219132,
#  'type': 218743,
#  'receptor': 218601,
#  'development': 217586,
#  'serum': 216005,
#  'model': 215819,
#  'factors': 214131,
#  'total': 212780,
#  'respectively': 209548,
#  'health': 209505,
#  'suggest': 206975,
#  'case': 205185,
#  'rat': 205085,
#  'days': 204985,
#  'low': 204952,
#  'factor': 202635,
#  'presence': 201606,
#  'level': 201244,
#  'women': 200559,
#  'similar': 199739,
#  'number': 199203,
#  'proteins': 199032,
#  'tumor': 196907,
#  'tissue': 196631,
#  'studied': 195933,
#  'concentrations': 194727,
#  'specific': 193696,
#  'subjects': 187612,
#  'following': 186209,
#  'acute': 182107,
#  'performed': 181786,
#  'diagnosis': 181527,
#  'liver': 179922,
#  'lower': 179003,
#  'induced': 177994,
#  'treated': 177853,
#  'obtained': 177525,
#  'care': 176878,
#  'months': 174700,
#  'findings': 174679,
#  'reduced': 174560,
#  'primary': 173857,
#  'infection': 173735,
#  'important': 173493,
#  'early': 173056,
#  'test': 171639,
#  'concentration': 171393,
#  'vitro': 171264,
#  'decreased': 168158,
#  'activation': 165240,
#  'differences': 164853,
#  'measured': 164798,
#  'chronic': 162398,
#  'brain': 161525,
#  'reported': 161344,
#  'addition': 159067,
#  'potential': 158136,
#  'pressure': 157696,
#  'period': 155729,
#  'report': 154849,
#  'surgery': 154169,
#  'bone': 153398,
#  'evidence': 153342,
#  'examined': 152865,
#  'membrane': 152846,
#  'greater': 150806,
#  'muscle': 150143,
#  'determined': 150050,
#  'related': 148945,
#  'genes': 148045,
#  'conditions': 147617,
#  'identified': 146213,
#  'renal': 145569,
#  'drug': 145557,
#  'based': 143361,
#  'heart': 142954,
#  'major': 142497,
#  'demonstrated': 142124,
#  'virus': 141527,
#  'including': 141508,
#  'isolated': 141472,
#  'syndrome': 141226,
#  'positive': 141126,
#  'dose': 140425,
#  'complex': 140285,
#  'small': 139746,
#  'responses': 139437,
#  'revealed': 138332,
#  'inhibition': 137979,
#  'values': 137907,
#  'formation': 136531,
#  'production': 136151,
#  'developed': 135914,
#  'investigated': 135296,
#  'shown': 134880,
#  'enzyme': 134132,
#  'conclusions': 133323,
#  'single': 133003,
#  'population': 132794,
#  'molecular': 132140,
#  'surface': 131151,
#  'region': 130678,
#  'administration': 129955,
#  'survival': 129869,
#  'possible': 129470,
#  'range': 128991,
#  'detected': 128247,
#  'large': 127135,
#  'animals': 126848,
#  'determine': 126664,
#  'medical': 125094,
#  'vivo': 124806,
#  'synthesis': 124228,
#  'structure': 123561,
#  'functional': 123385,
#  'samples': 123269,
#  'sequence': 122840,
#  'rates': 122640,
#  'body': 122524,
#  'exposure': 122056,
#  'receptors': 121870,
#  'flow': 121749,
#  'weeks': 121695,
#  'conclusion': 121315,
#  'weight': 119611,
#  'contrast': 118979,
#  'antibodies': 118871,
#  'lung': 118547,
#  'release': 118403,
#  'controls': 118016,
#  'common': 117806,
#  'species': 117680,
#  'involved': 117507,
#  'decrease': 116060,
#  'indicate': 115813,
#  'change': 115642,
#  'reduction': 115626,
#  'day': 115374,
#  'lesions': 114862,
#  'effective': 114825,
#  'surgical': 114594,
#  'stimulation': 114514,
#  'phase': 113906,
#  'site': 113557,
#  'mechanism': 113341,
#  'active': 112953,
#  'degrees': 112863,
#  'evaluation': 112645,
#  'sites': 112128,
#  'tumors': 111360,
#  '100': 111269,
#  'caused': 110665,
#  'produced': 110562,
#  'reaction': 110461,
#  'information': 110049,
#  'technique': 109970,
#  'symptoms': 109442,
#  'loss': 109403,
#  'evaluated': 109232,
#  'multiple': 109103,
#  'mrna': 109085,
#  'research': 108385,
#  'left': 108333,
#  'experimental': 108080,
#  'cardiac': 108042,
#  'previously': 107612,
#  'pain': 106554,
#  'review': 106483,
#  'objective': 106343,
#  'process': 106126,
#  'carcinoma': 105967,
#  'pulmonary': 105832,
#  'form': 105782,
#  'background': 105647,
#  'difference': 105532,
#  'severe': 105511,
#  'family': 105192,
#  'known': 104409,
#  'management': 104373,
#  'mechanisms': 103488,
#  'hospital': 103406,
#  'antibody': 103211,
#  'properties': 103053,
#  'described': 101910,
#  'resistance': 101542,
#  'expressed': 101148,
#  'ratio': 100941,
#  'required': 100602,
#  'relationship': 100260,
#  'artery': 100145,
#  'neurons': 100020,
#  'distribution': 99953,
#  'mouse': 99819,
#  'approximately': 99644,
#  'comparison': 99602,
#  'area': 99576,
#  'current': 99368,
#  'coronary': 98963,
#  'alpha': 98598,
#  'influence': 97685,
#  'presented': 97607,
#  'detection': 97451,
#  'size': 97429,
#  'frequency': 96858,
#  'given': 96714,
#  'injury': 96667,
#  'incidence': 96627,
#  'association': 96625,
#  'min': 96610,
#  'tested': 96352,
#  'drugs': 96306,
#  'result': 96276,
#  'mortality': 96232,
#  'approach': 95984,
#  'amino': 95749,
#  'male': 95427,
#  'adult': 95191,
#  'value': 95028,
#  'second': 94963,
#  'sensitivity': 94927,
#  'glucose': 94922,
#  'assay': 94918,
#  'general': 94846,
#  'action': 94226,
#  'failure': 93999,
#  'water': 93609,
#  'skin': 93537,
#  'genetic': 93295,
#  'insulin': 93257,
#  'inhibited': 92976,
#  'mass': 92017,
#  'provide': 91991,
#  'kinase': 91634,
#  'followed': 91470,
#  'follow-up': 91458,
#  'diseases': 91395,
#  'correlation': 91088,
#  'oral': 90974,
#  'outcome': 90663,
#  'types': 90593,
#  'breast': 90582,
#  'vascular': 90578,
#  'containing': 90466,
#  'occurred': 90336,
#  'strains': 90020,
#  '0.05': 89707,
#  'relative': 88926,
#  'stress': 88460,
#  'support': 88255,
#  'cellular': 87947,
#  'pattern': 87813,
#  'death': 87681,
#  'characteristics': 87658,
#  'calcium': 87530,
#  'negative': 87208,
#  'included': 87030,
#  'state': 86996,
#  'seen': 86991,
#  'culture': 86883,
#  'central': 86564,
#  'initial': 86469,
#  'interaction': 86226,
#  'healthy': 85686,
#  'activities': 85686,
#  'peripheral': 85401,
#  'highly': 85289,
#  'content': 85273,
#  'order': 85071,
#  'combination': 85049,
#  'discussed': 84991,
#  'parameters': 84847,
#  'novel': 84646,
#  'assessed': 84604,
#  'status': 84389,
#  'ability': 84333,
#  'experiments': 84027,
#  'regulation': 83789,
#  'men': 83786,
#  'systems': 83725,
#  'stage': 83670,
#  'received': 83465,
#  'complications': 83257,
#  'inhibitor': 83238,
#  'nerve': 83209,
#  'tissues': 82860,
#  'quality': 82802,
#  'procedure': 82512,
#  'volume': 81958,
#  'ventricular': 81888,
#  'cause': 81594,
#  'antigen': 81452,
#  'rna': 81281,
#  'resulted': 81069,
#  'injection': 80814,
#  'free': 80393,
#  'induction': 80238,
#  'recent': 79835,
#  'analyzed': 79272,
#  'long-term': 79232,
#  'direct': 79173,
#  'indicated': 79074,
#  'previous': 78958,
#  'metabolism': 78953,
#  'therapeutic': 78863,
#  'increases': 78778,
#  'imaging': 78701,
#  'considered': 78670,
#  'design': 78657,
#  'life': 78484,
#  'acids': 78482,
#  'overall': 78306,
#  'purpose': 78250,
#  'agents': 78215,
#  'beta': 78107,
#  'assessment': 78077,
#  'examination': 77558,
#  'disorders': 77314,
#  'available': 77264,
#  'immune': 76929,
#  'complete': 76791,
#  'correlated': 76686,
#  'standard': 76414,
#  'secretion': 76356,
#  'increasing': 76330,
#  'times': 76029,
#  'doses': 76007,
#  'measurements': 75548,
#  'regions': 75239,
#  'female': 74978,
#  'average': 74928,
#  'suggested': 74853,
#  'suggesting': 74655,
#  'local': 74558,
#  'tests': 74372,
#  'diabetes': 74265,
#  'microm': 74052,
#  'patterns': 74011,
#  'performance': 73975,
#  'combined': 73905,
#  'work': 73757,
#  'peptide': 73676,
#  'features': 73636,
#  'diagnostic': 73625,
#  'absence': 73310,
#  'affected': 73283,
#  'techniques': 73242,
#  'useful': 72986,
#  'myocardial': 72927,
#  'suggests': 72838,
#  'right': 72218,
#  'demonstrate': 72147,
#  'pregnancy': 71993,
#  'index': 71634,
#  'uptake': 71534,
#  'rapid': 71451,
#  'areas': 71425,
#  'individual': 71375,
#  'models': 71068,
#  'nuclear': 70900,
#  'evaluate': 70756,
#  'versus': 70621,
#  'year': 70590,
#  'mg/kg': 70536,
#  'compounds': 70394,
#  'cerebral': 70373,
#  'lines': 70201,
#  'basis': 70188,
#  'efficacy': 70084,
#  'sequences': 70064,
#  'improved': 70001,
#  'likely': 69979,
#  'characterized': 69853,
#  'pathway': 69789,
#  'mutations': 69588,
#  'light': 69446,
#  'hours': 69234,
#  'enhanced': 69105,
#  'hormone': 68637,
#  'prevalence': 68545,
#  'temperature': 68040,
#  'duration': 67841,
#  'transcription': 67629,
#  'additional': 67354,
#  'transport': 67341,
#  'coli': 67264,
#  'hypertension': 67189,
#  'fluid': 67144,
#  'medium': 67140,
#  'differentiation': 67124,
#  'respiratory': 67111,
#  'application': 67084,
#  'problems': 66927,
#  'proliferation': 66857,
#  'arterial': 66731,
#  'physical': 66726,
#  'damage': 66719,
#  'strain': 66599,
#  'sample': 66535,
#  'oxygen': 66358,
#  'behavior': 66283,
#  'domain': 66242,
#  'chain': 66087,
#  'better': 66055,
#  'secondary': 65884,
#  'interactions': 65876,
#  'gastric': 65873,
#  'sodium': 65841,
#  'density': 65837,
#  'target': 65660,
#  'history': 65125,
#  'good': 65041,
#  'course': 65014,
#  'main': 64791,
#  'infections': 64789,
#  'intracellular': 64728,
#  'individuals': 64565,
#  'exercise': 64003,
#  'ca2': 63985,
#  'practice': 63892,
#  'inhibitors': 63792,
#  'literature': 63765,
#  'elevated': 63677,
#  'structures': 63385,
#  'and/or': 63296,
#  'line': 63190,
#  'components': 62805,
#  'infants': 62803,
#  'structural': 62770,
#  'postoperative': 62651,
#  'apoptosis': 62567,
#  'mutant': 62516,
#  'measures': 62489,
#  'hepatic': 62339,
#  'lipid': 62320,
#  'urinary': 62264,
#  'biological': 62227,
#  'screening': 62213,
#  'independent': 62201,
#  'solution': 62092,
#  'applied': 61946,
#  'furthermore': 61852,
#  'consistent': 61676,
#  'visual': 61620,
#  '0.01': 61598,
#  'kidney': 61389,
#  'assess': 61350,
#  'investigate': 61326,
#  'confirmed': 61269,
#  'series': 61260,
#  'energy': 61187,
#  'median': 61065,
#  'fetal': 61002,
#  'administered': 60809,
#  'degree': 60800,
#  'established': 60695,
#  'class': 60433,
#  'according': 60360,
#  'molecules': 60307,
#  'underwent': 60238,
#  'need': 60175,
#  'aim': 59998,
#  'experience': 59875,
#  'systemic': 59838,
#  'daily': 59795,
#  'electron': 59746,
#  'cycle': 59737,
#  'trials': 59727,
#  'iii': 59692,
#  'appears': 59683,
#  'length': 59555,
#  'field': 59540,
#  'essential': 59502,
#  'paper': 59463,
#  '0.001': 59341,
#  'young': 59224,
#  'events': 59195,
#  'transplantation': 59159,
#  'derived': 59136,
#  'malignant': 59071,
#  'cultures': 58969,
#  'endothelial': 58773,
#  'sensitive': 58669,
#  'processes': 58646,
#  'forms': 58604,
#  'signal': 58282,
#  'procedures': 58173,
#  'recovery': 58140,
#  'trial': 58140,
#  'identification': 58090,
#  'long': 57681,
#  'analyses': 57597,
#  'identify': 57456,
#  'affect': 57452,
#  'products': 57385,
#  'prior': 57287,
#  'spinal': 57088,
#  'functions': 56995,
#  'purified': 56802,
#  'diet': 56793,
#  'mutation': 56770,
#  'epithelial': 56723,
#  'selected': 56711,
#  'cholesterol': 56686,
#  'lymphocytes': 56523,
#  'determination': 56468,
#  'program': 56246,
#  'metabolic': 56172,
#  'play': 56052,
#  'inflammatory': 55976,
#  'end': 55919,
#  'selective': 55780,
#  'social': 55774,
#  'peak': 55528,
#  'authors': 55380,
#  'recently': 55205,
#  'inhibitory': 55167,
#  'seven': 55124,
#  'activated': 55098,
#  'specificity': 55043,
#  'transfer': 54949,
#  'residues': 54811,
#  'bacterial': 54809,
#  'anterior': 54463,
#  'testing': 54278,
#  'infusion': 54064,
#  'indicating': 53981,
#  'impact': 53954,
#  'dependent': 53905,
#  'chemotherapy': 53881,
#  'disorder': 53848,
#  'lead': 53835,
#  'means': 53778,
#  'criteria': 53753,
#  'capacity': 53658,
#  'viral': 53648,
#  'defined': 53630,
#  'adults': 53589,
#  'component': 53478,
#  'onset': 53427,
#  'baseline': 53424,
#  'exposed': 53281,
#  'importance': 53236,
#  'enzymes': 53233,
#  'improvement': 53151,
#  'subsequent': 53146,
#  'affinity': 53125,
#  'resulting': 53026,
#  'extent': 53003,
#  'distinct': 52959,
#  'depression': 52763,
#  'simple': 52755,
#  'measurement': 52668,
#  'especially': 52574,
#  'radiation': 52496,
#  'laboratory': 52457,
#  'cortex': 52436,
#  'limited': 52395,
#  'percent': 52387,
#  'critical': 52367,
#  'cultured': 52345,
#  'involvement': 52256,
#  'maximum': 52206,
#  'quantitative': 52188,
#  'despite': 52073,
#  'occur': 52031,
#  'vs.': 52013,
#  'membranes': 52012,
#  'natural': 51865,
#  'infected': 51760,
#  'phosphorylation': 51687,
#  'basal': 51648,
#  'hypothesis': 51643,
#  'controlled': 51623,
#  'training': 51436,
#  'fraction': 51433,
#  'animal': 51349,
#  'partial': 51322,
#  'stable': 51059,
#  'late': 50972,
#  'conducted': 50946,
#  'chromosome': 50893,
#  'reactions': 50699,
#  'monoclonal': 50620,
#  'prevention': 50590,
#  'causes': 50588,
#  'proposed': 50568,
#  'complexes': 50525,
#  'taken': 50504,
#  'relatively': 50412,
#  'necessary': 50297,
#  'little': 50270,
#  'position': 50265,
#  'toxicity': 50157,
#  'relation': 50052,
#  'populations': 49792,
#  'provided': 49594,
#  'carried': 49547,
#  'food': 49489,
#  'motor': 49486,
#  'corresponding': 49413,
#  'achieved': 49386,
#  'states': 49338,
#  'chemical': 49197,
#  'sex': 49174,
#  'accumulation': 49154,
#  'hepatitis': 49080,
#  'promoter': 48936,
#  'knowledge': 48905,
#  'interval': 48894,
#  'intestinal': 48868,
#  'signaling': 48845,
#  'conventional': 48754,
#  'recorded': 48728,
#  'provides': 48726,
#  'aged': 48602,
#  'remained': 48418,
#  'internal': 48394,
#  'markers': 48329,
#  'particularly': 48268,
#  'diabetic': 48268,
#  'later': 48167,
#  'nucleus': 48117,
#  'mediated': 48055,
#  'intervention': 47939,
#  'extracellular': 47905,
#  'characterization': 47816,
#  'collected': 47777,
#  'microscopy': 47690,
#  'intake': 47585,
#  'fatty': 47454,
#  'cardiovascular': 47334,
#  'recombinant': 47318,
#  'particular': 47288,
#  'variation': 47234,
#  'substrate': 47172,
#  'delivery': 47039,
#  'marrow': 47038,
#  'alcohol': 46932,
#  'regression': 46921,
#  'specimens': 46874,
#  'conclude': 46861,
#  'rare': 46841,
#  'material': 46831,
#  'significance': 46805,
#  'repair': 46795,
#  'investigation': 46771,
#  'short': 46735,
#  'abnormalities': 46735,
#  'directly': 46728,
#  'stimulated': 46716,
#  'pathways': 46711,
#  'chromatography': 46710,
#  'differential': 46661,
#  'responsible': 46614,
#  'survey': 46587,
#  'monitoring': 46560,
#  'understanding': 46498,
#  'wall': 46461,
#  'tract': 46352,
#  'nursing': 46067,
#  'dogs': 46047,
#  'describe': 46015,
#  'antigens': 46005,
#  'statistically': 45875,
#  'physiological': 45790,
#  'randomized': 45760,
#  'having': 45694,
#  'agent': 45608,
#  'induce': 45574,
#  'abnormal': 45567,
#  'variables': 45531,
#  'peptides': 45475,
#  'intravenous': 45414,
#  'calculated': 45402,
#  'frequently': 45153,
#  'education': 45133,
#  'prospective': 45096,
#  'include': 45076,
#  'point': 45031,
#  'males': 44984,
#  'improve': 44965,
#  'condition': 44960,
#  'modified': 44959,
#  'aortic': 44934,
#  'future': 44920,
#  'older': 44788,
#  'magnetic': 44659,
#  'birth': 44614,
#  'diagnosed': 44598,
#  'aspects': 44501,
#  '0.5': 44493,
#  'outcomes': 44460,
#  'estimated': 44428,
#  'bacteria': 44407,
#  'problem': 44348,
#  'strong': 44303,
#  'biopsy': 44247,
#  'exhibited': 44228,
#  'lesion': 44206,
#  'reduce': 44147,
#  'developing': 44144,
#  'urine': 44130,
#  'spontaneous': 44051,
#  'isolates': 43944,
#  'thyroid': 43937,
#  'measure': 43897,
#  'deficiency': 43614,
#  'able': 43595,
#  'hiv': 43584,
#  'pancreatic': 43552,
#  'head': 43545,
#  'scores': 43526,
#  'child': 43395,
#  'cervical': 43384,
#  'score': 43375,
#  'observations': 43343,
#  'severity': 43320,
#  'appeared': 43317,
#  'marked': 43278,
#  'gel': 43252,
#  'females': 43249,
#  'platelet': 43239,
#  'staining': 43207,
#  'located': 43176,
#  'reviewed': 43173,
#  'matrix': 43173,
#  'produce': 43154,
#  'occurs': 43072,
#  'i.e.': 42983,
#  'alternative': 42980,
#  'dysfunction': 42941,
#  'poor': 42897,
#  'implications': 42843,
#  'apparent': 42675,
#  'strongly': 42618,
#  'cord': 42604,
#  'lack': 42571,
#  'progression': 42541,
#  'constant': 42459,
#  'appear': 42428,
#  'origin': 42406,
#  'product': 42371,
#  'highest': 42345,
#  'examine': 42330,
#  'neuronal': 42314,
#  'hand': 42311,
#  'leukemia': 42289,
#  'appropriate': 42285,
#  'open': 42222,
#  'intact': 42213,
#  'operation': 42145,
#  'mainly': 42138,
#  'old': 42104,
#  'vitamin': 42102,
#  'probably': 42066,
#  'removal': 42059,
#  'infarction': 41939,
#  'article': 41906,
#  'mitochondrial': 41882,
#  'scale': 41836,
#  'certain': 41803,
#  'continuous': 41730,
#  'biochemical': 41641,
#  'placebo': 41640,
#  'stages': 41602,
#  'shows': 41526,
#  'collagen': 41423,
#  'lateral': 41410,
#  'clinically': 41383,
#  'bovine': 41357,
#  'selection': 41313,
#  'percentage': 41243,
#  'medicine': 41111,
#  'macrophages': 41057,
#  'variety': 41004,
#  'potent': 40926,
#  'remains': 40904,
#  'contribute': 40892,
#  'elderly': 40868,
#  'fat': 40824,
#  'altered': 40775,
#  'escherichia': 40775,
#  'rabbit': 40654,
#  'upper': 40641,
#  'endogenous': 40623,
#  'linear': 40617,
#  'reports': 40509,
#  'maternal': 40488,
#  'resonance': 40471,
#  'alterations': 40364,
#  'prostate': 40279,
#  'formed': 40278,
#  'setting': 40204,
#  'host': 40194,
#  'assays': 40191,
#  'manner': 40160,
#  'unit': 40046,
#  'fluorescence': 40011,
#  'adverse': 39855,
#  'receiving': 39833,
#  'mutants': 39575,
#  'resection': 39538,
#  'participants': 39489,
#  'dietary': 39455,
#  'abdominal': 39446,
#  'week': 39416,
#  'contained': 39342,
#  'venous': 39282,
#  'set': 39172,
#  'smoking': 39014,
#  'successful': 38997,
#  'completely': 38991,
#  'develop': 38961,
#  'channel': 38907,
#  'localization': 38840,
#  'composition': 38820,
#  'generated': 38759,
#  'reference': 38740,
#  'materials': 38705,
#  'humans': 38673,
#  'iron': 38668,
#  'degradation': 38648,
#  'terms': 38619,
#  'larger': 38504,
#  'advanced': 38491,
#  'strategies': 38485,
#  'community': 38432,
#  'absorption': 38378,
#  'prolonged': 38372,
#  'liquid': 38282,
#  'posterior': 38188,
#  'marker': 38172,
#  'services': 38150,
#  'cortical': 38030,
#  'tumour': 38002,
#  'source': 37999,
#  'lymph': 37996,
#  'preparation': 37969,
#  'nature': 37942,
#  'regulatory': 37879,
#  'pathogenesis': 37878,
#  'moderate': 37863,
#  'processing': 37818,
#  'designed': 37778,
#  'prepared': 37775,
#  'rapidly': 37642,
#  'mental': 37579,
#  'treatments': 37570,
#  'nervous': 37527,
#  'recurrent': 37513,
#  'graft': 37512,
#  'intensity': 37474,
#  'transient': 37428,
#  'asthma': 37413,
#  'antagonist': 37341,
#  'inhibit': 37321,
#  'contact': 37298,
#  'transmission': 37277,
#  'people': 37262,
#  'inflammation': 37255,
#  'needed': 37208,
#  'predicted': 37198,
#  'best': 37182,
#  'murine': 37180,
#  'longer': 37143,
#  'stability': 37119,
#  'wild-type': 37036,
#  'necrosis': 37020,
#  'subunit': 36974,
#  'stroke': 36973,
#  'cdna': 36909,
#  'maximal': 36902,
#  'dental': 36838,
#  'bladder': 36774,
#  'safety': 36719,
#  'white': 36709,
#  'proportion': 36645,
#  'generation': 36644,
#  'bound': 36618,
#  'environmental': 36580,
#  'distal': 36561,
#  'key': 36519,
#  'mild': 36466,
#  'national': 36463,
#  'images': 36462,
#  'basic': 36450,
#  'sleep': 36442,
#  'ovarian': 36430,
#  'eye': 36329,
#  'concluded': 36275,
#  'memory': 36264,
#  'noted': 36248,
#  'involving': 36203,
#  'plus': 36125,
#  'majority': 35953,
#  'red': 35926,
#  'consecutive': 35912,
#  'led': 35910,
#  'elements': 35891,
#  'laser': 35854,
#  'experiment': 35844,
#  'consumption': 35787,
#  'recognition': 35724,
#  'signs': 35698,
#  'joint': 35669,
#  'environment': 35664,
#  'identical': 35658,
#  'frequent': 35612,
#  'oxide': 35590,
#  '250': 35588,
#  'polymerase': 35554,
#  'external': 35515,
#  'recurrence': 35505,
#  'pcr': 35490,
#  'channels': 35461,
#  'molecule': 35451,
#  'atrial': 35417,
#  '0.1': 35410,
#  'markedly': 35397,
#  'minutes': 35386,
#  'phenotype': 35285,
#  'generally': 35262,
#  'usually': 35183,
#  'numbers': 35119,
#  'ischemia': 35100,
#  'adhesion': 35087,
#  'man': 35063,
#  'comparable': 35046,
#  'stem': 34998,
#  'impaired': 34951,
#  'respect': 34946,
#  'neural': 34941,
#  'prevent': 34840,
#  'injuries': 34756,
#  'unique': 34739,
#  'units': 34726,
#  'words': 34703,
#  ...}

# %%
terms =[]
for idx,key in enumerate(freq):
    terms.append(key)
    if idx==49999:
        break

# %%
terms
# Out:
# ['patients',
#  'cells',
#  'results',
#  'study',
#  'treatment',
#  'cell',
#  'activity',
#  'protein',
#  'group',
#  'effect',
#  'human',
#  'disease',
#  'effects',
#  'increased',
#  'levels',
#  'clinical',
#  'found',
#  'analysis',
#  'expression',
#  'data',
#  'significantly',
#  'studies',
#  'significant',
#  'blood',
#  'compared',
#  'control',
#  'different',
#  'gene',
#  'associated',
#  'cases',
#  'showed',
#  'high',
#  'response',
#  'observed',
#  'use',
#  'normal',
#  'acid',
#  'years',
#  'methods',
#  'rate',
#  'changes',
#  'cancer',
#  'time',
#  'patient',
#  'system',
#  'rats',
#  'increase',
#  'role',
#  'age',
#  'present',
#  'groups',
#  'therapy',
#  'higher',
#  'growth',
#  'dna',
#  'new',
#  'function',
#  'risk',
#  'method',
#  'binding',
#  'children',
#  'mice',
#  'plasma',
#  'mean',
#  'type',
#  'receptor',
#  'development',
#  'serum',
#  'model',
#  'factors',
#  'total',
#  'respectively',
#  'health',
#  'suggest',
#  'case',
#  'rat',
#  'days',
#  'low',
#  'factor',
#  'presence',
#  'level',
#  'women',
#  'similar',
#  'number',
#  'proteins',
#  'tumor',
#  'tissue',
#  'studied',
#  'concentrations',
#  'specific',
#  'subjects',
#  'following',
#  'acute',
#  'performed',
#  'diagnosis',
#  'liver',
#  'lower',
#  'induced',
#  'treated',
#  'obtained',
#  'care',
#  'months',
#  'findings',
#  'reduced',
#  'primary',
#  'infection',
#  'important',
#  'early',
#  'test',
#  'concentration',
#  'vitro',
#  'decreased',
#  'activation',
#  'differences',
#  'measured',
#  'chronic',
#  'brain',
#  'reported',
#  'addition',
#  'potential',
#  'pressure',
#  'period',
#  'report',
#  'surgery',
#  'bone',
#  'evidence',
#  'examined',
#  'membrane',
#  'greater',
#  'muscle',
#  'determined',
#  'related',
#  'genes',
#  'conditions',
#  'identified',
#  'renal',
#  'drug',
#  'based',
#  'heart',
#  'major',
#  'demonstrated',
#  'virus',
#  'including',
#  'isolated',
#  'syndrome',
#  'positive',
#  'dose',
#  'complex',
#  'small',
#  'responses',
#  'revealed',
#  'inhibition',
#  'values',
#  'formation',
#  'production',
#  'developed',
#  'investigated',
#  'shown',
#  'enzyme',
#  'conclusions',
#  'single',
#  'population',
#  'molecular',
#  'surface',
#  'region',
#  'administration',
#  'survival',
#  'possible',
#  'range',
#  'detected',
#  'large',
#  'animals',
#  'determine',
#  'medical',
#  'vivo',
#  'synthesis',
#  'structure',
#  'functional',
#  'samples',
#  'sequence',
#  'rates',
#  'body',
#  'exposure',
#  'receptors',
#  'flow',
#  'weeks',
#  'conclusion',
#  'weight',
#  'contrast',
#  'antibodies',
#  'lung',
#  'release',
#  'controls',
#  'common',
#  'species',
#  'involved',
#  'decrease',
#  'indicate',
#  'change',
#  'reduction',
#  'day',
#  'lesions',
#  'effective',
#  'surgical',
#  'stimulation',
#  'phase',
#  'site',
#  'mechanism',
#  'active',
#  'degrees',
#  'evaluation',
#  'sites',
#  'tumors',
#  '100',
#  'caused',
#  'produced',
#  'reaction',
#  'information',
#  'technique',
#  'symptoms',
#  'loss',
#  'evaluated',
#  'multiple',
#  'mrna',
#  'research',
#  'left',
#  'experimental',
#  'cardiac',
#  'previously',
#  'pain',
#  'review',
#  'objective',
#  'process',
#  'carcinoma',
#  'pulmonary',
#  'form',
#  'background',
#  'difference',
#  'severe',
#  'family',
#  'known',
#  'management',
#  'mechanisms',
#  'hospital',
#  'antibody',
#  'properties',
#  'described',
#  'resistance',
#  'expressed',
#  'ratio',
#  'required',
#  'relationship',
#  'artery',
#  'neurons',
#  'distribution',
#  'mouse',
#  'approximately',
#  'comparison',
#  'area',
#  'current',
#  'coronary',
#  'alpha',
#  'influence',
#  'presented',
#  'detection',
#  'size',
#  'frequency',
#  'given',
#  'injury',
#  'incidence',
#  'association',
#  'min',
#  'tested',
#  'drugs',
#  'result',
#  'mortality',
#  'approach',
#  'amino',
#  'male',
#  'adult',
#  'value',
#  'second',
#  'sensitivity',
#  'glucose',
#  'assay',
#  'general',
#  'action',
#  'failure',
#  'water',
#  'skin',
#  'genetic',
#  'insulin',
#  'inhibited',
#  'mass',
#  'provide',
#  'kinase',
#  'followed',
#  'follow-up',
#  'diseases',
#  'correlation',
#  'oral',
#  'outcome',
#  'types',
#  'breast',
#  'vascular',
#  'containing',
#  'occurred',
#  'strains',
#  '0.05',
#  'relative',
#  'stress',
#  'support',
#  'cellular',
#  'pattern',
#  'death',
#  'characteristics',
#  'calcium',
#  'negative',
#  'included',
#  'state',
#  'seen',
#  'culture',
#  'central',
#  'initial',
#  'interaction',
#  'healthy',
#  'activities',
#  'peripheral',
#  'highly',
#  'content',
#  'order',
#  'combination',
#  'discussed',
#  'parameters',
#  'novel',
#  'assessed',
#  'status',
#  'ability',
#  'experiments',
#  'regulation',
#  'men',
#  'systems',
#  'stage',
#  'received',
#  'complications',
#  'inhibitor',
#  'nerve',
#  'tissues',
#  'quality',
#  'procedure',
#  'volume',
#  'ventricular',
#  'cause',
#  'antigen',
#  'rna',
#  'resulted',
#  'injection',
#  'free',
#  'induction',
#  'recent',
#  'analyzed',
#  'long-term',
#  'direct',
#  'indicated',
#  'previous',
#  'metabolism',
#  'therapeutic',
#  'increases',
#  'imaging',
#  'considered',
#  'design',
#  'life',
#  'acids',
#  'overall',
#  'purpose',
#  'agents',
#  'beta',
#  'assessment',
#  'examination',
#  'disorders',
#  'available',
#  'immune',
#  'complete',
#  'correlated',
#  'standard',
#  'secretion',
#  'increasing',
#  'times',
#  'doses',
#  'measurements',
#  'regions',
#  'female',
#  'average',
#  'suggested',
#  'suggesting',
#  'local',
#  'tests',
#  'diabetes',
#  'microm',
#  'patterns',
#  'performance',
#  'combined',
#  'work',
#  'peptide',
#  'features',
#  'diagnostic',
#  'absence',
#  'affected',
#  'techniques',
#  'useful',
#  'myocardial',
#  'suggests',
#  'right',
#  'demonstrate',
#  'pregnancy',
#  'index',
#  'uptake',
#  'rapid',
#  'areas',
#  'individual',
#  'models',
#  'nuclear',
#  'evaluate',
#  'versus',
#  'year',
#  'mg/kg',
#  'compounds',
#  'cerebral',
#  'lines',
#  'basis',
#  'efficacy',
#  'sequences',
#  'improved',
#  'likely',
#  'characterized',
#  'pathway',
#  'mutations',
#  'light',
#  'hours',
#  'enhanced',
#  'hormone',
#  'prevalence',
#  'temperature',
#  'duration',
#  'transcription',
#  'additional',
#  'transport',
#  'coli',
#  'hypertension',
#  'fluid',
#  'medium',
#  'differentiation',
#  'respiratory',
#  'application',
#  'problems',
#  'proliferation',
#  'arterial',
#  'physical',
#  'damage',
#  'strain',
#  'sample',
#  'oxygen',
#  'behavior',
#  'domain',
#  'chain',
#  'better',
#  'secondary',
#  'interactions',
#  'gastric',
#  'sodium',
#  'density',
#  'target',
#  'history',
#  'good',
#  'course',
#  'main',
#  'infections',
#  'intracellular',
#  'individuals',
#  'exercise',
#  'ca2',
#  'practice',
#  'inhibitors',
#  'literature',
#  'elevated',
#  'structures',
#  'and/or',
#  'line',
#  'components',
#  'infants',
#  'structural',
#  'postoperative',
#  'apoptosis',
#  'mutant',
#  'measures',
#  'hepatic',
#  'lipid',
#  'urinary',
#  'biological',
#  'screening',
#  'independent',
#  'solution',
#  'applied',
#  'furthermore',
#  'consistent',
#  'visual',
#  '0.01',
#  'kidney',
#  'assess',
#  'investigate',
#  'confirmed',
#  'series',
#  'energy',
#  'median',
#  'fetal',
#  'administered',
#  'degree',
#  'established',
#  'class',
#  'according',
#  'molecules',
#  'underwent',
#  'need',
#  'aim',
#  'experience',
#  'systemic',
#  'daily',
#  'electron',
#  'cycle',
#  'trials',
#  'iii',
#  'appears',
#  'length',
#  'field',
#  'essential',
#  'paper',
#  '0.001',
#  'young',
#  'events',
#  'transplantation',
#  'derived',
#  'malignant',
#  'cultures',
#  'endothelial',
#  'sensitive',
#  'processes',
#  'forms',
#  'signal',
#  'procedures',
#  'recovery',
#  'trial',
#  'identification',
#  'long',
#  'analyses',
#  'identify',
#  'affect',
#  'products',
#  'prior',
#  'spinal',
#  'functions',
#  'purified',
#  'diet',
#  'mutation',
#  'epithelial',
#  'selected',
#  'cholesterol',
#  'lymphocytes',
#  'determination',
#  'program',
#  'metabolic',
#  'play',
#  'inflammatory',
#  'end',
#  'selective',
#  'social',
#  'peak',
#  'authors',
#  'recently',
#  'inhibitory',
#  'seven',
#  'activated',
#  'specificity',
#  'transfer',
#  'residues',
#  'bacterial',
#  'anterior',
#  'testing',
#  'infusion',
#  'indicating',
#  'impact',
#  'dependent',
#  'chemotherapy',
#  'disorder',
#  'lead',
#  'means',
#  'criteria',
#  'capacity',
#  'viral',
#  'defined',
#  'adults',
#  'component',
#  'onset',
#  'baseline',
#  'exposed',
#  'importance',
#  'enzymes',
#  'improvement',
#  'subsequent',
#  'affinity',
#  'resulting',
#  'extent',
#  'distinct',
#  'depression',
#  'simple',
#  'measurement',
#  'especially',
#  'radiation',
#  'laboratory',
#  'cortex',
#  'limited',
#  'percent',
#  'critical',
#  'cultured',
#  'involvement',
#  'maximum',
#  'quantitative',
#  'despite',
#  'occur',
#  'vs.',
#  'membranes',
#  'natural',
#  'infected',
#  'phosphorylation',
#  'basal',
#  'hypothesis',
#  'controlled',
#  'training',
#  'fraction',
#  'animal',
#  'partial',
#  'stable',
#  'late',
#  'conducted',
#  'chromosome',
#  'reactions',
#  'monoclonal',
#  'prevention',
#  'causes',
#  'proposed',
#  'complexes',
#  'taken',
#  'relatively',
#  'necessary',
#  'little',
#  'position',
#  'toxicity',
#  'relation',
#  'populations',
#  'provided',
#  'carried',
#  'food',
#  'motor',
#  'corresponding',
#  'achieved',
#  'states',
#  'chemical',
#  'sex',
#  'accumulation',
#  'hepatitis',
#  'promoter',
#  'knowledge',
#  'interval',
#  'intestinal',
#  'signaling',
#  'conventional',
#  'recorded',
#  'provides',
#  'aged',
#  'remained',
#  'internal',
#  'markers',
#  'particularly',
#  'diabetic',
#  'later',
#  'nucleus',
#  'mediated',
#  'intervention',
#  'extracellular',
#  'characterization',
#  'collected',
#  'microscopy',
#  'intake',
#  'fatty',
#  'cardiovascular',
#  'recombinant',
#  'particular',
#  'variation',
#  'substrate',
#  'delivery',
#  'marrow',
#  'alcohol',
#  'regression',
#  'specimens',
#  'conclude',
#  'rare',
#  'material',
#  'significance',
#  'repair',
#  'investigation',
#  'short',
#  'abnormalities',
#  'directly',
#  'stimulated',
#  'pathways',
#  'chromatography',
#  'differential',
#  'responsible',
#  'survey',
#  'monitoring',
#  'understanding',
#  'wall',
#  'tract',
#  'nursing',
#  'dogs',
#  'describe',
#  'antigens',
#  'statistically',
#  'physiological',
#  'randomized',
#  'having',
#  'agent',
#  'induce',
#  'abnormal',
#  'variables',
#  'peptides',
#  'intravenous',
#  'calculated',
#  'frequently',
#  'education',
#  'prospective',
#  'include',
#  'point',
#  'males',
#  'improve',
#  'condition',
#  'modified',
#  'aortic',
#  'future',
#  'older',
#  'magnetic',
#  'birth',
#  'diagnosed',
#  'aspects',
#  '0.5',
#  'outcomes',
#  'estimated',
#  'bacteria',
#  'problem',
#  'strong',
#  'biopsy',
#  'exhibited',
#  'lesion',
#  'reduce',
#  'developing',
#  'urine',
#  'spontaneous',
#  'isolates',
#  'thyroid',
#  'measure',
#  'deficiency',
#  'able',
#  'hiv',
#  'pancreatic',
#  'head',
#  'scores',
#  'child',
#  'cervical',
#  'score',
#  'observations',
#  'severity',
#  'appeared',
#  'marked',
#  'gel',
#  'females',
#  'platelet',
#  'staining',
#  'located',
#  'reviewed',
#  'matrix',
#  'produce',
#  'occurs',
#  'i.e.',
#  'alternative',
#  'dysfunction',
#  'poor',
#  'implications',
#  'apparent',
#  'strongly',
#  'cord',
#  'lack',
#  'progression',
#  'constant',
#  'appear',
#  'origin',
#  'product',
#  'highest',
#  'examine',
#  'neuronal',
#  'hand',
#  'leukemia',
#  'appropriate',
#  'open',
#  'intact',
#  'operation',
#  'mainly',
#  'old',
#  'vitamin',
#  'probably',
#  'removal',
#  'infarction',
#  'article',
#  'mitochondrial',
#  'scale',
#  'certain',
#  'continuous',
#  'biochemical',
#  'placebo',
#  'stages',
#  'shows',
#  'collagen',
#  'lateral',
#  'clinically',
#  'bovine',
#  'selection',
#  'percentage',
#  'medicine',
#  'macrophages',
#  'variety',
#  'potent',
#  'remains',
#  'contribute',
#  'elderly',
#  'fat',
#  'altered',
#  'escherichia',
#  'rabbit',
#  'upper',
#  'endogenous',
#  'linear',
#  'reports',
#  'maternal',
#  'resonance',
#  'alterations',
#  'prostate',
#  'formed',
#  'setting',
#  'host',
#  'assays',
#  'manner',
#  'unit',
#  'fluorescence',
#  'adverse',
#  'receiving',
#  'mutants',
#  'resection',
#  'participants',
#  'dietary',
#  'abdominal',
#  'week',
#  'contained',
#  'venous',
#  'set',
#  'smoking',
#  'successful',
#  'completely',
#  'develop',
#  'channel',
#  'localization',
#  'composition',
#  'generated',
#  'reference',
#  'materials',
#  'humans',
#  'iron',
#  'degradation',
#  'terms',
#  'larger',
#  'advanced',
#  'strategies',
#  'community',
#  'absorption',
#  'prolonged',
#  'liquid',
#  'posterior',
#  'marker',
#  'services',
#  'cortical',
#  'tumour',
#  'source',
#  'lymph',
#  'preparation',
#  'nature',
#  'regulatory',
#  'pathogenesis',
#  'moderate',
#  'processing',
#  'designed',
#  'prepared',
#  'rapidly',
#  'mental',
#  'treatments',
#  'nervous',
#  'recurrent',
#  'graft',
#  'intensity',
#  'transient',
#  'asthma',
#  'antagonist',
#  'inhibit',
#  'contact',
#  'transmission',
#  'people',
#  'inflammation',
#  'needed',
#  'predicted',
#  'best',
#  'murine',
#  'longer',
#  'stability',
#  'wild-type',
#  'necrosis',
#  'subunit',
#  'stroke',
#  'cdna',
#  'maximal',
#  'dental',
#  'bladder',
#  'safety',
#  'white',
#  'proportion',
#  'generation',
#  'bound',
#  'environmental',
#  'distal',
#  'key',
#  'mild',
#  'national',
#  'images',
#  'basic',
#  'sleep',
#  'ovarian',
#  'eye',
#  'concluded',
#  'memory',
#  'noted',
#  'involving',
#  'plus',
#  'majority',
#  'red',
#  'consecutive',
#  'led',
#  'elements',
#  'laser',
#  'experiment',
#  'consumption',
#  'recognition',
#  'signs',
#  'joint',
#  'environment',
#  'identical',
#  'frequent',
#  'oxide',
#  '250',
#  'polymerase',
#  'external',
#  'recurrence',
#  'pcr',
#  'channels',
#  'molecule',
#  'atrial',
#  '0.1',
#  'markedly',
#  'minutes',
#  'phenotype',
#  'generally',
#  'usually',
#  'numbers',
#  'ischemia',
#  'adhesion',
#  'man',
#  'comparable',
#  'stem',
#  'impaired',
#  'respect',
#  'neural',
#  'prevent',
#  'injuries',
#  'unique',
#  'units',
#  'words',
#  ...]

# %%
terms = [(" " + x + " ").lower() for x in terms]

# %%
import pandas as pd
import xml.etree.ElementTree as ET
import spacy
import numpy as np
from pathlib import Path
import itertools
from concurrent.futures import ProcessPoolExecutor
import os
import pickle

# %%
directory = "Processed/"
files = Path(directory).glob('*.txt')
files = list(files)

# %%
top100 = list(itertools.islice(files, 0,100))

# %%
zipped = list([top100[0:25],top100[25:50],top100[50:75],top100[75:100]])

# %%
def my_function3(files):    
    term_freq ={}
    for file in files:
        name =  os.path.basename(file)
        term_freq[name] = []
        print(f'starting for {name}')
        with open(file,'r') as f:
            lines = f.readlines()
            for line in lines:
                doclst = {}
                m = line.split(' ',1)[1]
                for word in terms:
                    c = m.count(word)
                    if c>0:
                        doclst[word] = c
                term_freq[name].append(doclst)           
    return term_freq

# %%
with ProcessPoolExecutor(max_workers=4) as exe:
    results = exe.map(my_function3,zipped)
# Out:
# starting for 12.txtstarting for 277.txtstarting for 361.txtstarting for 481.txt
#
#
#
# starting for 138.txt
# starting for 279.txt
# starting for 406.txt
# starting for 417.txt
# starting for 501.txt
# starting for 160.txt
# starting for 370.txt
# starting for 152.txt
# starting for 44.txt
# starting for 533.txt
# starting for 459.txt
# starting for 294.txt
# starting for 15.txt
# starting for 95.txt
# starting for 78.txt
# starting for 488.txt
# starting for 228.txt
# starting for 457.txt
# starting for 245.txt
# starting for 36.txt
# starting for 382.txt
# starting for 254.txt
# starting for 425.txt
# starting for 69.txt
# starting for 486.txt
# starting for 183.txt
# starting for 192.txt
# starting for 321.txt
# starting for 353.txt
# starting for 155.txt
# starting for 31.txt
# starting for 38.txt
# starting for 422.txt
# starting for 143.txt
# starting for 293.txt
# starting for 385.txt
# starting for 205.txt
# starting for 354.txt
# starting for 285.txt
# starting for 112.txt
# starting for 270.txt
# starting for 534.txt
# starting for 506.txt
# starting for 522.txt
# starting for 71.txt
# starting for 242.txt
# starting for 167.txt
# starting for 408.txt
# starting for 314.txt
# starting for 226.txt
# starting for 184.txt
# starting for 328.txt
# starting for 202.txt
# starting for 462.txt
# starting for 131.txt
# starting for 129.txt
# starting for 115.txt
# starting for 127.txt
# starting for 550.txt
# starting for 43.txt
# starting for 548.txt
# starting for 92.txt
# starting for 546.txt
# starting for 1.txt
# starting for 366.txt
# starting for 474.txt
# starting for 410.txt
# starting for 302.txt
# starting for 230.txt
# starting for 508.txt
# starting for 8.txt
# starting for 368.txt
# starting for 67.txt
# starting for 169.txt
# starting for 6.txt
# starting for 120.txt
# starting for 253.txt
# starting for 473.txt
# starting for 450.txt
# starting for 195.txt
# starting for 144.txt
# starting for 541.txt
# starting for 305.txt
# starting for 326.txt
# starting for 525.txt
# starting for 237.txt
# starting for 282.txt
# starting for 60.txt
# starting for 419.txt
# starting for 401.txt
# starting for 379.txt
# starting for 76.txt
# starting for 377.txt
# starting for 313.txt
# starting for 465.txt
# starting for 239.txt

# %%
k = list(results)
term_freq = {**k[0],**k[1],**k[2],**k[3]}

# %%
with open('term_freq_50000.pkl', 'wb') as f:
    pickle.dump(term_freq, f)

# %%
my_files = [os.path.basename(file) for file in top100]

# %%
my_files
# Out:
# ['277.txt',
#  '501.txt',
#  '160.txt',
#  '459.txt',
#  '488.txt',
#  '36.txt',
#  '382.txt',
#  '425.txt',
#  '353.txt',
#  '31.txt',
#  '422.txt',
#  '385.txt',
#  '354.txt',
#  '270.txt',
#  '506.txt',
#  '167.txt',
#  '328.txt',
#  '202.txt',
#  '115.txt',
#  '43.txt',
#  '92.txt',
#  '508.txt',
#  '169.txt',
#  '450.txt',
#  '326.txt',
#  '481.txt',
#  '279.txt',
#  '44.txt',
#  '95.txt',
#  '457.txt',
#  '486.txt',
#  '321.txt',
#  '38.txt',
#  '205.txt',
#  '112.txt',
#  '71.txt',
#  '314.txt',
#  '462.txt',
#  '127.txt',
#  '546.txt',
#  '230.txt',
#  '368.txt',
#  '120.txt',
#  '541.txt',
#  '237.txt',
#  '419.txt',
#  '76.txt',
#  '313.txt',
#  '465.txt',
#  '239.txt',
#  '361.txt',
#  '417.txt',
#  '152.txt',
#  '533.txt',
#  '294.txt',
#  '78.txt',
#  '245.txt',
#  '183.txt',
#  '155.txt',
#  '293.txt',
#  '534.txt',
#  '242.txt',
#  '184.txt',
#  '129.txt',
#  '548.txt',
#  '366.txt',
#  '410.txt',
#  '8.txt',
#  '253.txt',
#  '195.txt',
#  '144.txt',
#  '525.txt',
#  '282.txt',
#  '401.txt',
#  '377.txt',
#  '12.txt',
#  '138.txt',
#  '406.txt',
#  '370.txt',
#  '15.txt',
#  '228.txt',
#  '254.txt',
#  '69.txt',
#  '192.txt',
#  '143.txt',
#  '285.txt',
#  '522.txt',
#  '408.txt',
#  '226.txt',
#  '131.txt',
#  '550.txt',
#  '1.txt',
#  '474.txt',
#  '302.txt',
#  '67.txt',
#  '6.txt',
#  '473.txt',
#  '305.txt',
#  '60.txt',
#  '379.txt',
#  '221.txt',
#  '136.txt',
#  '557.txt',
#  '330.txt',
#  '497.txt',
#  '446.txt',
#  '84.txt',
#  '55.txt',
#  '268.txt',
#  '103.txt',
#  '214.txt',
#  '29.txt',
#  '104.txt',
#  '213.txt',
#  '490.txt',
#  '337.txt',
#  '441.txt',
#  '519.txt',
#  '83.txt',
#  '178.txt',
#  '52.txt',
#  '345.txt',
#  '394.txt',
#  '433.txt',
#  '20.txt',
#  '339.txt',
#  '517.txt',
#  '176.txt',
#  '261.txt',
#  '499.txt',
#  '448.txt',
#  '510.txt',
#  '171.txt',
#  '266.txt',
#  '342.txt',
#  '434.txt',
#  '393.txt',
#  '27.txt',
#  '154.txt',
#  '535.txt',
#  '292.txt',
#  '243.txt',
#  '185.txt',
#  '128.txt',
#  '549.txt',
#  '367.txt',
#  '411.txt',
#  '238.txt',
#  '360.txt',
#  '416.txt',
#  '153.txt',
#  '295.txt',
#  '532.txt',
#  '244.txt',
#  '79.txt',
#  '182.txt',
#  '121.txt',
#  '540.txt',
#  '236.txt',
#  '418.txt',
#  '77.txt',
#  '312.txt',
#  '464.txt',
#  '70.txt',
#  '315.txt',
#  '463.txt',
#  '126.txt',
#  '547.txt',
#  '231.txt',
#  '369.txt',
#  '45.txt',
#  '278.txt',
#  '94.txt',
#  '456.txt',
#  '320.txt',
#  '487.txt',
#  '204.txt',
#  '39.txt',
#  '113.txt',
#  '203.txt',
#  '114.txt',
#  '42.txt',
#  '509.txt',
#  '93.txt',
#  '168.txt',
#  '451.txt',
#  '480.txt',
#  '327.txt',
#  '30.txt',
#  '384.txt',
#  '423.txt',
#  '355.txt',
#  '271.txt',
#  '507.txt',
#  '166.txt',
#  '329.txt',
#  '276.txt',
#  '500.txt',
#  '161.txt',
#  '458.txt',
#  '489.txt',
#  '37.txt',
#  '424.txt',
#  '383.txt',
#  '352.txt',
#  '498.txt',
#  '449.txt',
#  '511.txt',
#  '170.txt',
#  '267.txt',
#  '343.txt',
#  '392.txt',
#  '435.txt',
#  '26.txt',
#  '344.txt',
#  '432.txt',
#  '395.txt',
#  '21.txt',
#  '338.txt',
#  '516.txt',
#  '177.txt',
#  '260.txt',
#  '105.txt',
#  '212.txt',
#  '336.txt',
#  '491.txt',
#  '440.txt',
#  '82.txt',
#  '518.txt',
#  '179.txt',
#  '53.txt',
#  '496.txt',
#  '331.txt',
#  '447.txt',
#  '85.txt',
#  '269.txt',
#  '54.txt',
#  '102.txt',
#  '28.txt',
#  '215.txt',
#  '7.txt',
#  '472.txt',
#  '304.txt',
#  '61.txt',
#  '378.txt',
#  '220.txt',
#  '137.txt',
#  '556.txt',
#  '409.txt',
#  '227.txt',
#  '130.txt',
#  '551.txt',
#  '475.txt',
#  '303.txt',
#  '66.txt',
#  '407.txt',
#  '371.txt',
#  '229.txt',
#  '14.txt',
#  '68.txt',
#  '255.txt',
#  '193.txt',
#  '142.txt',
#  '523.txt',
#  '284.txt',
#  '9.txt',
#  '252.txt',
#  '194.txt',
#  '145.txt',
#  '283.txt',
#  '524.txt',
#  '400.txt',
#  '376.txt',
#  '13.txt',
#  '139.txt',
#  '558.txt',
#  '347.txt',
#  '431.txt',
#  '396.txt',
#  '108.txt',
#  '22.txt',
#  '174.txt',
#  '515.txt',
#  '263.txt',
#  '173.txt',
#  '88.txt',
#  '512.txt',
#  '264.txt',
#  '59.txt',
#  '340.txt',
#  '391.txt',
#  '436.txt',
#  '25.txt',
#  '218.txt',
#  '495.txt',
#  '332.txt',
#  '444.txt',
#  '86.txt',
#  '57.txt',
#  '438.txt',
#  '101.txt',
#  '216.txt',
#  '349.txt',
#  '398.txt',
#  '106.txt',
#  '211.txt',
#  '335.txt',
#  '492.txt',
#  '443.txt',
#  '81.txt',
#  '50.txt',
#  '224.txt',
#  '19.txt',
#  '552.txt',
#  '133.txt',
#  '476.txt',
#  '3.txt',
#  '300.txt',
#  '65.txt',
#  '258.txt',
#  '289.txt',
#  '471.txt',
#  '4.txt',
#  '307.txt',
#  '199.txt',
#  '62.txt',
#  '529.txt',
#  '148.txt',
#  '223.txt',
#  '555.txt',
#  '134.txt',
#  '309.txt',
#  '197.txt',
#  '251.txt',
#  '280.txt',
#  '527.txt',
#  '146.txt',
#  '403.txt',
#  '375.txt',
#  '10.txt',
#  '404.txt',
#  '372.txt',
#  '17.txt',
#  '478.txt',
#  '190.txt',
#  '256.txt',
#  '520.txt',
#  '287.txt',
#  '141.txt',
#  '363.txt',
#  '415.txt',
#  '296.txt',
#  '531.txt',
#  '150.txt',
#  '181.txt',
#  '247.txt',
#  '469.txt',
#  '536.txt',
#  '291.txt',
#  '157.txt',
#  '186.txt',
#  '240.txt',
#  '318.txt',
#  '364.txt',
#  '412.txt',
#  '538.txt',
#  '159.txt',
#  '188.txt',
#  '73.txt',
#  '316.txt',
#  '460.txt',
#  '544.txt',
#  '125.txt',
#  '232.txt',
#  '543.txt',
#  '122.txt',
#  '235.txt',
#  '298.txt',
#  '249.txt',
#  '74.txt',
#  '311.txt',
#  '467.txt',
#  '200.txt',
#  '117.txt',
#  '389.txt',
#  '358.txt',
#  '41.txt',
#  '90.txt',
#  '452.txt',
#  '483.txt',
#  '324.txt',
#  '46.txt',
#  '97.txt',
#  '455.txt',
#  '323.txt',
#  '484.txt',
#  '207.txt',
#  '110.txt',
#  '429.txt',
#  '48.txt',
#  '275.txt',
#  '162.txt',
#  '503.txt',
#  '99.txt',
#  '209.txt',
#  '34.txt',
#  '427.txt',
#  '380.txt',
#  '351.txt',
#  '33.txt',
#  '119.txt',
#  '387.txt',
#  '420.txt',
#  '356.txt',
#  '272.txt',
#  '165.txt',
#  '504.txt',
#  '405.txt',
#  '373.txt',
#  '16.txt',
#  '479.txt',
#  '191.txt',
#  '257.txt',
#  '286.txt',
#  '521.txt',
#  '140.txt',
#  '308.txt',
#  '196.txt',
#  '250.txt',
#  '526.txt',
#  '281.txt',
#  '147.txt',
#  '402.txt',
#  '374.txt',
#  '11.txt',
#  '470.txt',
#  '5.txt',
#  '306.txt',
#  '198.txt',
#  '63.txt',
#  '528.txt',
#  '149.txt',
#  '222.txt',
#  '554.txt',
#  '135.txt',
#  '18.txt',
#  '225.txt',
#  '553.txt',
#  '132.txt',
#  '477.txt',
#  '2.txt',
#  '301.txt',
#  '259.txt',
#  '64.txt',
#  '288.txt',
#  '348.txt',
#  '399.txt',
#  '107.txt',
#  '210.txt',
#  '493.txt',
#  '334.txt',
#  '442.txt',
#  '80.txt',
#  '51.txt',
#  '333.txt',
#  '494.txt',
#  '445.txt',
#  '87.txt',
#  '56.txt',
#  '439.txt',
#  '100.txt',
#  '217.txt',
#  '172.txt',
#  '513.txt',
#  '89.txt',
#  '58.txt',
#  '265.txt',
#  '341.txt',
#  '437.txt',
#  '390.txt',
#  '219.txt',
#  '24.txt',
#  '346.txt',
#  '397.txt',
#  '430.txt',
#  '109.txt',
#  '23.txt',
#  '175.txt',
#  '514.txt',
#  '262.txt',
#  '32.txt',
#  '118.txt',
#  '421.txt',
#  '386.txt',
#  '357.txt',
#  '273.txt',
#  '164.txt',
#  '505.txt',
#  '274.txt',
#  '49.txt',
#  '163.txt',
#  '98.txt',
#  '502.txt',
#  '35.txt',
#  '208.txt',
#  '381.txt',
#  '426.txt',
#  '350.txt',
#  '47.txt',
#  '96.txt',
#  '454.txt',
#  '485.txt',
#  '322.txt',
#  '206.txt',
#  '111.txt',
#  '428.txt',
#  '201.txt',
#  '116.txt',
#  '388.txt',
#  '359.txt',
#  '40.txt',
#  '91.txt',
#  '453.txt',
#  '325.txt',
#  '482.txt',
#  '542.txt',
#  '123.txt',
#  '234.txt',
#  '299.txt',
#  '75.txt',
#  '248.txt',
#  '310.txt',
#  '466.txt',
#  '539.txt',
#  '158.txt',
#  '189.txt',
#  '72.txt',
#  '317.txt',
#  '461.txt',
#  '545.txt',
#  '124.txt',
#  '233.txt',
#  '290.txt',
#  '537.txt',
#  '156.txt',
#  '187.txt',
#  '241.txt',
#  '319.txt',
#  '365.txt',
#  '413.txt',
#  '362.txt',
#  '414.txt',
#  '530.txt',
#  '297.txt',
#  '151.txt',
#  '180.txt',
#  '246.txt',
#  '468.txt']

# %%
with open('mwe_100000.pkl', 'rb') as f:
    top100000 = pickle.load(f)

# %%
with open('tokens_final.pkl', 'rb') as f:
    MWE = pickle.load(f)

# %%
i=0
mwe_dict = {}
for key in top100000:
    mwe_dict[key] = i
    i=i+1

i=0
term_dict = {}
for key in set(terms):
    term_dict[key] = i
    i=i+1

# %%
matrix = np.zeros((len(mwe_dict),len(term_dict)))

# %%
for file in my_files:
    mwe_lst = MWE[file]
    term_lst = term_freq[file]
    for i in range(0,30000):
        d1 = mwe_lst[i]
        d2 = term_lst[i]
        if (len(d1)>0 and len(d2)>0):
            for mwe in d1:
                if mwe in mwe_dict:
                    for t in d2:
                        matrix[mwe_dict[mwe],term_dict[t]] +=d1[mwe]*d2[t]

# %%
reverse_dict_mwe = {mwe_dict[k]:k for k in mwe_dict.keys()}
reverse_dict_terms = {term_dict[k]:k for k in term_dict.keys()}

# %%
clusters = []
with open('out.output_100000.tsv.I35', 'r') as f:
     lines = f.readlines()
     for line in lines:
        clusters.append(line.split('\t'))

# %%
term_cluster = {}

# %%
for col in range(matrix.shape[1]):
    arr = matrix[:,col]
    term_cluster[reverse_dict_terms[col]] = []
    for cluster in clusters:
        s = 0
        for mwe in cluster:
            if mwe in mwe_dict:
                if (arr[mwe_dict[mwe]]>2):
                    s+=1
        term_cluster[reverse_dict_terms[col]].append(s)

# %%
with open('term_cluster_50000.pkl', 'wb') as f:
    pickle.dump(term_cluster, f)

# %%
with open('terms_50000.pkl', 'wb') as f:
    pickle.dump(terms, f)

# %%
with open('term_cluster_50000.pkl', 'rb') as f:
    term_cluster = pickle.load(f)

# %%
my_dict = {}
for term in term_cluster:
    lst =[]
    for idx,elem in enumerate(term_cluster[term]):
        lst.append(elem/len(clusters[idx]))
    my_dict[term] = lst

# %%
new_dict = {}
for term in my_dict:
    lst=[]
    for idx,elem in enumerate(my_dict[term]):
        if elem >0.5:
            lst.append(idx)
    new_dict[term] = lst

# %%
count =0
for term in new_dict:
    if len(new_dict[term])>1:
        count+=1
print(count)
# Out:
# 25642

# %%
part_dict ={}
for term in term_cluster:
    flag = False
    for idx,elem in enumerate(term_cluster[term]):
        if elem >=1:
            flag =True
    part_dict[term] = flag

# %%
count = 0
for term in part_dict:
    if ((part_dict[term] == True)):
        count+=1
print(count)
# Out:
# 49674

# %%
25642/49674
# Out:
# 0.5162056609091276

# %%
terms = []
